# %% [markdown]
# <a href="https://colab.research.google.com/github/SondipPoulSingh/Math/blob/main/Neurone_abaro_Anuranan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### Solution

# %%
1. Fill up the 5 litre mug
2. Pour the water into 3 litre mug
3. 2 litre water remains
4. Empty the 3 litre mug and pour the remaining 2 litre from 5 litre mug.
5. Again fill the 5 litre mug and pour one litre to the 3 litre mug.

# %% [markdown]
# #### Q 203

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### Solution
# The Combination forms using three colored cups are.
# WBR
# WRB
# RWB
# RBW
# BRW
# BWR
# Analyzing the patterns BRW is the correct form. Where B->Black, W->White, R->Red

# %% [markdown]
# #### Q 212

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
